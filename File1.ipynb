# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Entertainment/output_25.xlsx')
df
# Out:
#                                               Headline  \
# 0    شاہ رخ خان شہرہ افاق ڈرامے کسوٹی زندگی کی کا ح...
# 1    بھارتی معروف ہدایتکار کرن جوہر اپنے پاکستانی ہ...
# 2    بھارتی اداکارہ جوہی چاولا مختصر دورہ پاکستان ک...
# 3    فاطمہ ثریا بجیا کے یوم پیدائش پر گوگل کا خصوصی...
# 4        بھارت کی معروف اداکارہ جوہی چاولا کی کراچی مد
# ..                                                 ...
# 994  عتیق الرحمن خاوند نہیں جھوٹا انسان ہے اداکارہ ...
# 995    کامیابی کیلئے شاہ رخ بھی عامر خان کے نقش قدم پر
# 996  انوشکا نے ویرات سے شادی کی خبروں کو ایک بار پھ...
# 997     ایشوریا رائے کو ایک اور فلم میں کاسٹ کرلیا گیا
# 998  گول مال اگین اور سیکرٹ سپر اسٹار کی کمائی کی ا...
#
#                                              News Text       Category  \
# 0    بالی وڈ اسٹار شاہ رخ خان مشہور بھارتی ٹی وی ڈر...  Entertainment
# 1    سوشل میڈیا پر اکثر مشہور شخصیات کے مشابہ چہروں...  Entertainment
# 2    کراچی بھارتی اداکارہ جوہی چاولا پاکستان کے مخت...  Entertainment
# 3    لازوال ڈراموں کی مصنفہ اردو ناول نگار اورمعروف...  Entertainment
# 4    مشہور بھارتی اداکارہ جوہی چاولا ان دنوں کراچی ...  Entertainment
# ..                                                 ...            ...
# 994  لاہور لالی وڈ اداکارہ میرا نے عدالت میں بیان ر...  Entertainment
# 995  بالی وڈ اداکار شاہ رخ خان نے اپنی فلموں کی کام...  Entertainment
# 996  بھارتی کرکٹ ٹیم کے کپتان ویرات کوہلی اور بالی ...  Entertainment
# 997  بھارتی خوبرو اداکارہ ایشوریا رائے بچن اپنی حال...  Entertainment
# 998  ابھی گول مال اور سیکرٹ سپر اسٹار کی ٹکر کے ابت...  Entertainment
#
#      News length                                    First 100 Words  \
# 0           1199  بالی وڈ اسٹار شاہ رخ خان مشہور بھارتی ٹی وی ڈر...
# 1            965  سوشل میڈیا پر اکثر مشہور شخصیات کے مشابہ چہروں...
# 2            951  کراچی بھارتی اداکارہ جوہی چاولا پاکستان کے مخت...
# 3           1451  لازوال ڈراموں کی مصنفہ اردو ناول نگار اورمعروف...
# 4            699  مشہور بھارتی اداکارہ جوہی چاولا ان دنوں کراچی ...
# ..           ...                                                ...
# 994          627  بالی وڈ اداکار شاہ رخ خان نے اپنی فلموں کی کام...
# 995         1259  بھارتی کرکٹ ٹیم کے کپتان ویرات کوہلی اور بالی ...
# 996         1438  بھارتی خوبرو اداکارہ ایشوریا رائے بچن اپنی حال...
# 997         1195  ابھی گول مال اور سیکرٹ سپر اسٹار کی ٹکر کے ابت...
# 998         4627                                                NaN
#
#     Subcategory
# 0       Fashion
# 1       Fashion
# 2       Fashion
# 3          Film
# 4       Fashion
# ..          ...
# 994     Fashion
# 995     Fashion
# 996     Fashion
# 997     Fashion
# 998        Film
#
# [999 rows x 6 columns]

# %% [markdown]
# ## Step 1:
# #### If any news record contains sentences of less than 10 words than discard that record.

# %%
pip install pyarabic
# Out:
# Requirement already satisfied: pyarabic in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.6.15)
# Requirement already satisfied: six>=1.14.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyarabic) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Below given code is only for macbook users whose nltk library doesn't work directly

# %%
import ssl
# Bypass SSL verification
ssl._create_default_https_context = ssl._create_unverified_context

# %%
from pyarabic.araby import tokenize
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import sent_tokenize
nltk.download('punkt')

NewsText_words = []
urdu_sentences = df['News Text']
for i, sent in enumerate(urdu_sentences):
    words = word_tokenize(sent)
    for word in words:
        NewsText_words.append(word)
    

NewsText_words
# Out:
# [nltk_data] Downloading package punkt to /Users/urwah/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['بالی',
#  'وڈ',
#  'اسٹار',
#  'شاہ',
#  'رخ',
#  'خان',
#  'مشہور',
#  'بھارتی',
#  'ٹی',
#  'وی',
#  'ڈرامے',
#  'کسوٹی',
#  'زندگی',
#  'کی',
#  'کے',
#  'دوسرے',
#  'سیزن',
#  'کا',
#  'حصہ',
#  'بن',
#  'گئےبھارتی',
#  'ٹی',
#  'وی',
#  'کامشہور',
#  'ڈرامہ',
#  'کسوٹی',
#  'زندگی',
#  'کی',
#  'تقریبا',
#  'سال',
#  'ٹی',
#  'وی',
#  'پر',
#  'ان',
#  'ایئر',
#  'رہا',
#  'ہے',
#  'جس',
#  'کے',
#  'مرکزی',
#  'کردار',
#  'انوراگ',
#  'باسو',
#  'اور',
#  'پریرنا',
#  'شرما',
#  'تھے',
#  'جو',
#  'کہ',
#  'سیزین',
#  'خان',
#  'اور',
#  'شویتا',
#  'تیواری',
#  'نے',
#  'سر',
#  'انجام',
#  'دیے',
#  'تھےڈرامے',
#  'کی',
#  'پروڈیوسر',
#  'ایکتا',
#  'کپور',
#  'ہیں',
#  'جنہوں',
#  'نے',
#  'اب',
#  '10',
#  'سال',
#  'بعد',
#  'ایک',
#  'بار',
#  'پھر',
#  'کسوٹی',
#  'زندگی',
#  'کی',
#  'کو',
#  'چھوٹی',
#  'اسکرین',
#  'پر',
#  'لانے',
#  'کی',
#  'ٹھان',
#  'لی',
#  'ہےبھارتی',
#  'ڈرامے',
#  'کسوٹی',
#  'زندگی',
#  'کی',
#  'کا',
#  'نیا',
#  'سیزن',
#  'رواں',
#  'ماہ',
#  'شروع',
#  'ہوگا',
#  'جس',
#  'میں',
#  'کئی',
#  'پرانے',
#  'چہرے',
#  'نہیں',
#  'ہوں',
#  'گے',
#  'جب',
#  'کہ',
#  'پریرنا',
#  'اور',
#  'انوراگ',
#  'کے',
#  'کردار',
#  'بھی',
#  'نئے',
#  'اداکار',
#  'کریں',
#  'گےڈرامے',
#  'کے',
#  'نئے',
#  'سیزن',
#  'میں',
#  'سلور',
#  'اسکرین',
#  'کے',
#  'بادشاہ',
#  'سمجھے',
#  'جانے',
#  'والے',
#  'اداکار',
#  'شاہ',
#  'رخ',
#  'خان',
#  'بھی',
#  'ہیں',
#  'جو',
#  'کہ',
#  'ڈرامے',
#  'کے',
#  'کرداروں',
#  'کا',
#  'تعارف',
#  'پیش',
#  'کریں',
#  'گے',
#  'شاہ',
#  'رخ',
#  'خان',
#  'ڈرامے',
#  'میں',
#  'اداکاری',
#  'کرتے',
#  'نظر',
#  'نہیں',
#  'ائیں',
#  'گے',
#  'لیکن',
#  'شروعاتی',
#  'اقساط',
#  'میں',
#  'بیک',
#  'گرانڈ',
#  'میں',
#  'ان',
#  'کی',
#  'اواز',
#  'سنی',
#  'جاسکے',
#  'گی',
#  '2018',
#  '232',
#  'ڈرامے',
#  'کی',
#  'پروڈیوسر',
#  'ایکتا',
#  'کپور',
#  'نے',
#  'کسوٹی',
#  'زندگی',
#  'کی',
#  'کے',
#  'سیزن',
#  'کا',
#  'پرومو',
#  'جاری',
#  'کیا',
#  'ہے',
#  'جس',
#  'میں',
#  'کنگ',
#  'خان',
#  'بھی',
#  'نظر',
#  'ارہے',
#  'ہیں',
#  'اور',
#  'پرومو',
#  'سوشل',
#  'میڈیا',
#  'پر',
#  'بے',
#  'حد',
#  'پسند',
#  'کیا',
#  'جارہا',
#  'ہےدوسری',
#  'جانب',
#  'بھارتی',
#  'میڈیا',
#  'میں',
#  'خبریں',
#  'بھی',
#  'زیر',
#  'گردش',
#  'ہیں',
#  'کہ',
#  'شاہ',
#  'رخ',
#  'خان',
#  'نے',
#  'ڈرامے',
#  'کے',
#  'پرومو',
#  'شوٹ',
#  'کے',
#  'لیے',
#  'کروڑ',
#  'بھارتی',
#  'روپے',
#  'معاوضہ',
#  'وصول',
#  'کیا',
#  'ہےواضح',
#  'رہے',
#  'کہ',
#  'کسوٹی',
#  'زندگی',
#  'کی',
#  'کے',
#  'دوسرے',
#  'سیزن',
#  'میں',
#  'پریرنا',
#  'شرما',
#  'کے',
#  'کردار',
#  'ایریکا',
#  'فرنینڈس',
#  'اور',
#  'انوراگ',
#  'باسو',
#  'کا',
#  'کردار',
#  'پرتھ',
#  'سمتھان',
#  'کریں',
#  'گے',
#  'سوشل',
#  'میڈیا',
#  'پر',
#  'اکثر',
#  'مشہور',
#  'شخصیات',
#  'کے',
#  'مشابہ',
#  'چہروں',
#  'کے',
#  'چرچے',
#  'ہوتے',
#  'رہتے',
#  'ہیں',
#  'ایسے',
#  'میں',
#  'ایک',
#  'پاکستانی',
#  'مداحبھارتی',
#  'فلم',
#  'ساز',
#  'ہدایت',
#  'کار',
#  'کرن',
#  'جوہر',
#  'سے',
#  'اتنی',
#  'مماثلت',
#  'رکھتے',
#  'ہیں',
#  'کہ',
#  'خود',
#  'کرن',
#  'جوہر',
#  'بھی',
#  'ان',
#  'کی',
#  'تصویر',
#  'دیکھ',
#  'کر',
#  'حیران',
#  'رہ',
#  'گئےحال',
#  'ہی',
#  'میں',
#  'کرن',
#  'جوہر',
#  'نے',
#  'میوزک',
#  'کے',
#  'حوالے',
#  'سے',
#  'ایک',
#  'ٹوئٹ',
#  'شیئر',
#  'کی',
#  'تھی',
#  'جس',
#  'پر',
#  'ایک',
#  'پاکستانی',
#  'مداح',
#  'عثمان',
#  'خان',
#  'نے',
#  'تبصرہ',
#  'کرتے',
#  'ہوئے',
#  'اپنی',
#  'تصویر',
#  'شیئر',
#  'کی',
#  'اور',
#  'کرن',
#  'جوہر',
#  'سے',
#  'پوچھا',
#  'کہ',
#  'لوگ',
#  'کہتے',
#  'ہیں',
#  'میں',
#  'سے',
#  'ملتا',
#  'ہوں',
#  'کیا',
#  'ایسا',
#  'ہےجس',
#  'کے',
#  'جواب',
#  'میں',
#  'کرن',
#  'جوہر',
#  'کا',
#  'کہنا',
#  'تھا',
#  'کہ',
#  'کچھ',
#  'ٹوئٹس',
#  'مجھے',
#  'کچھ',
#  'کہنے',
#  'سے',
#  'بے',
#  'زبان',
#  'کردیتی',
#  'ہیں',
#  'اور',
#  'یہ',
#  'ان',
#  'میں',
#  'سے',
#  'ایک',
#  'ہےبعد',
#  'ازاں',
#  'یہ',
#  'ٹوئٹ',
#  'وائرل',
#  'ہوگئی',
#  'اور',
#  'اس',
#  'پر',
#  'مداحوں',
#  'کی',
#  'جانب',
#  'سے',
#  'دلچسپ',
#  'تبصرے',
#  'بھی',
#  'شروع',
#  'ہوگئےکرن',
#  'جوہر',
#  'بھارتی',
#  'ٹی',
#  'وی',
#  'چینل',
#  'کے',
#  'پروگرام',
#  'کافی',
#  'ود',
#  'کرن',
#  'کے',
#  'میزبان',
#  'بھی',
#  'ہیں',
#  'اسی',
#  'حوالے',
#  'سے',
#  'گٹار',
#  'بالی',
#  'وڈ',
#  'نامی',
#  'ایک',
#  'پیج',
#  'کی',
#  'جانب',
#  'سے',
#  'کہا',
#  'گیا',
#  'کہ',
#  'یہ',
#  'تو',
#  'کاپی',
#  'ود',
#  'کرن',
#  'ہےبابو',
#  'بھیا',
#  'نامی',
#  'ٹوئٹر',
#  'صارف',
#  'نے',
#  'مشورہ',
#  'دیا',
#  'کہ',
#  'سر',
#  'اپنی',
#  'بایوپک',
#  'بنائیں',
#  'اور',
#  'اس',
#  'میں',
#  'مرکزی',
#  'کردار',
#  'میں',
#  'انہیں',
#  'لے',
#  'لیںجیانتھ',
#  'کرشنان',
#  'نامی',
#  'مداح',
#  'نے',
#  'لکھا',
#  'لڑکے',
#  'تم',
#  'بہت',
#  'ملتے',
#  'ہو',
#  'کرن',
#  'جوہر',
#  'کا',
#  'ئینہ',
#  'ہوجب',
#  'کہ',
#  'ایک',
#  'صارف',
#  'نے',
#  'تو',
#  'انہیں',
#  'ڈپلیکیٹ',
#  'قرار',
#  'دے',
#  'دیا',
#  'کراچی',
#  'بھارتی',
#  'اداکارہ',
#  'جوہی',
#  'چاولا',
#  'پاکستان',
#  'کے',
#  'مختصر',
#  'دورے',
#  'کے',
#  'بعد',
#  'دبئی',
#  'روانہ',
#  'ہوگئیںجوہی',
#  'چاولا',
#  'کچھ',
#  'روز',
#  'قبل',
#  'کراچی',
#  'ئی',
#  'تھیں',
#  'جہاں',
#  'انہوں',
#  'نے',
#  'خوب',
#  'سیر',
#  'سپاٹے',
#  'کیےاداکارہ',
#  'نےکراچی',
#  'میں',
#  'اپنی',
#  'موجودگی',
#  'کے',
#  'حوالے',
#  'سے',
#  'ٹوئٹر',
#  'کے',
#  'ذریعے',
#  'پرستاروں',
#  'کو',
#  'گاہ',
#  'کرتے',
#  'ہوئے',
#  'ایک',
#  'تصویر',
#  'بھی',
#  'شیئر',
#  'کی',
#  'تھیجوہی',
#  'نے',
#  'لکھا',
#  'تھا',
#  'کہ',
#  'وہ',
#  'پاکستانی',
#  'فلم',
#  'جوانی',
#  'پھر',
#  'نہیں',
#  'نی',
#  'بھی',
#  'دیکھیں',
#  'گی',
#  'جس',
#  'میں',
#  'ایک',
#  'بھارتی',
#  'لڑکی',
#  'اور',
#  'پاکستانی',
#  'لڑکے',
#  'کی',
#  'رومانوی',
#  'کہانی',
#  'دکھائی',
#  'گئی',
#  'ہےاداکارہ',
#  'نے',
#  'کراچی',
#  'میں',
#  'اپنی',
#  'موجودگی',
#  'کے',
#  'حوالے',
#  'ٹوئٹر',
#  'کے',
#  'ذریعے',
#  'پرستاروں',
#  'کو',
#  'گاہ',
#  'کیا',
#  'اور',
#  'پیغام',
#  'کے',
#  'ساتھ',
#  'ایک',
#  'تصویر',
#  'بھی',
#  'شیئر',
#  'کیجوہی',
#  'چاولا',
#  'کراچی',
#  'سے',
#  'دبئی',
#  'کے',
#  'لیے',
#  'روانہ',
#  'ہوگئیںاس',
#  'موقع',
#  'پر',
#  'ایئرپورٹ',
#  'پر',
#  'میڈیا',
#  'سے',
#  'مختصر',
#  'گفتگو',
#  'میں',
#  'جوہی',
#  'چاولا',
#  'نے',
#  'بتایا',
#  'کہ',
#  'انہیں',
#  'پاکستانی',
#  'فلم',
#  'بہت',
#  'پسند',
#  'ئی',
#  'ساتھ',
#  'ہی',
#  'انہوں',
#  'نے',
#  'پاکستانی',
#  'اسٹارز',
#  'کو',
#  'داد',
#  'بھی',
#  'دیاداکارہ',
#  'نے',
#  'بتایا',
#  'کہ',
#  'میں',
#  'اپنے',
#  'رشتے',
#  'داروں',
#  'سے',
#  'ملنے',
#  'ائی',
#  'تھی',
#  'اس',
#  'لیے',
#  'کسی',
#  'کو',
#  'وقت',
#  'نہیں',
#  'دے',
#  'سکیجوہی',
#  'چاولا',
#  'نے',
#  'خاص',
#  'طور',
#  'پر',
#  'پاکستانی',
#  'کھانوں',
#  'کی',
#  'بھی',
#  'تعریف',
#  'کیواضح',
#  'رہے',
#  'کہ',
#  'اداکارہ',
#  'اس',
#  'سے',
#  'قبل',
#  '2013',
#  'اور',
#  '2016',
#  'میں',
#  'بھی',
#  'ایک',
#  'خاندانی',
#  'شادی',
#  'کے',
#  'سلسلے',
#  'میں',
#  'کراچی',
#  'کا',
#  'دورہ',
#  'کرچکی',
#  'ہیں',
#  'لازوال',
#  'ڈراموں',
#  'کی',
#  'مصنفہ',
#  'اردو',
#  'ناول',
#  'نگار',
#  'اورمعروف',
#  'ادیبہ',
#  'فاطمہ',
#  'ثریا',
#  'بجیا',
#  'کی',
#  '88',
#  'ویں',
#  'سالگرہ',
#  'پر',
#  'گوگل',
#  'بھی',
#  'اپنے',
#  'ڈوڈل',
#  'کے',
#  'ذریعے',
#  'خراج',
#  'عقیدت',
#  'پیش',
#  'کر',
#  'رہا',
#  'ہےفاطمہ',
#  'ثریا',
#  'بجیا',
#  'یکم',
#  'سمتبر',
#  '1930',
#  'کو',
#  'بھارتی',
#  'شہر',
#  'حیدرباد',
#  'میں',
#  'پیدا',
#  'ہوئیں',
#  'اور',
#  'قیام',
#  'پاکستان',
#  'کے',
#  'بعد',
#  'اپنے',
#  'اہل',
#  'خانہ',
#  'کے',
#  'ساتھ',
#  'کراچی',
#  'میں',
#  'سکونت',
#  'اختیار',
#  'کیفاطمہ',
#  'ثریا',
#  'بجیا',
#  'کا',
#  'تعلق',
#  'ایک',
#  'ایسے',
#  'گھرانے',
#  'سے',
#  'تھا',
#  'جہاں',
#  'سب',
#  'کو',
#  'ہی',
#  'ادب',
#  'سے',
#  'بہت',
#  'لگا',
#  'تھا',
#  'یہی',
#  'وجہ',
#  'ہے',
#  'کہ',
#  'انہیں',
#  'بھی',
#  'بچپن',
#  'سے',
#  'لکھنے',
#  'لکھانے',
#  'اور',
#  'مطالعے',
#  'کا',
#  'شوق',
#  'تھافاطمہ',
#  'ثریا',
#  'بجیا',
#  'ملک',
#  'کے',
#  'مشہور',
#  'مصنف',
#  'ادیب',
#  'انور',
#  'مقصود',
#  'شاعرہ',
#  'زہرہ',
#  'نگار',
#  'مرحوم',
#  'شیف',
#  'زبیدہ',
#  'طارق',
#  'اور',
#  'ڈیزائنر',
#  'کاظمی',
#  'کی',
#  'بہن',
#  'تھیں',
#  'انہوں',
#  'نے',
#  'باقاعدہ',
#  'اسکول',
#  'میں',
#  'تعلیم',
#  'حاصل',
#  'نہیں',
#  'کی',
#  'لیکن',
#  'گھر',
#  'میں',
#  'ہی',
#  'ان',
#  'کی',
#  'تعلیم',
#  'تربیت',
#  'کا',
#  'خاص',
#  'خیال',
#  'رکھا',
#  'گیا',
#  'فاطمہ',
#  'ثریا',
#  'بجیا',
#  '1960',
#  'میں',
#  'پاکستان',
#  'ٹیلی',
#  'ویژن',
#  'سے',
#  'منسلک',
#  'ہوئیں',
#  'جس',
#  'کے',
#  'بعد',
#  'پہلی',
#  'مرتبہ',
#  '1966',
#  'میں',
#  'انہوں',
#  'نے',
#  'اداکاری',
#  'کے',
#  'جوہر',
#  'دکھائے',
#  'اور',
#  'اس',
#  'کے',
#  'بعد',
#  'ڈرامے',
#  'لکھنے',
#  'کا',
#  'سلسلہ',
#  'شروع',
#  'کردیاان',
#  'کے',
#  'لکھے',
#  'گئے',
#  'مشہور',
#  'ڈراموں',
#  'میں',
#  'شمع',
#  'انا',
#  'تصویر',
#  'افشاں',
#  'عروسہ',
#  'اور',
#  'دیگر',
#  'شامل',
#  'ہیں',
#  'انہوں',
#  'نے',
#  'پی',
#  'ٹی',
#  'وی',
#  'پر',
#  'خواتین',
#  'کے',
#  'لیے',
#  'کئی',
#  'پروگرامز',
#  'کا',
#  'بھی',
#  'انعقاد',
#  'کیافاطمہ',
#  'ثریا',
#  'بجیا',
#  'نے',
#  'اپنی',
#  'بہترین',
#  'کارکردگی',
#  'سے',
#  'نہ',
#  'صرف',
#  'ملک',
#  'میں',
#  'نام',
#  'روشن',
#  'کیا',
#  'بلکہ',
#  'بین',
#  'الاقوامی',
#  'شہرت',
#  'بھی',
#  'حاصل',
#  'کیان',
#  'کی',
#  'خدمات',
#  'کے',
#  'اعتراف',
#  'میں',
#  'حکومت',
#  'پاکستان',
#  'نے',
#  'انہیں',
#  'تمغہ',
#  'برائے',
#  'حسن',
#  'کارکردگی',
#  'اور',
#  'ہلال',
#  'امتیاز',
#  'سے',
#  'نوازا',
#  'جب',
#  'کہ',
#  'جاپان',
#  'نے',
#  'بھی',
#  'انہیں',
#  'اپنا',
#  'اعلی',
#  'ترین',
#  'شہری',
#  'اعزاز',
#  'عطا',
#  'کیاانہوں',
#  'نے',
#  'سندھ',
#  'حکومت',
#  'کی',
#  'مشیر',
#  'برائے',
#  'تعلیم',
#  'کی',
#  'حیثیت',
#  'سے',
#  'بھی',
#  'خدمات',
#  'سرانجام',
#  'دیںفاطمہ',
#  'ثریا',
#  'بجیا',
#  'گلے',
#  'کے',
#  'کینسر',
#  'کے',
#  'باعث',
#  'شدید',
#  'علالت',
#  'کا',
#  'شکار',
#  'رہیں',
#  'اور',
#  '85',
#  'برس',
#  'کی',
#  'عمر',
#  'میں',
#  '22',
#  'مئی',
#  '2012',
#  'کو',
#  'کراچی',
#  'میں',
#  'انتقال',
#  'کرگئیں',
#  'لیکن',
#  'ان',
#  'کی',
#  'تحریریں',
#  'بھی',
#  'سب',
#  'کے',
#  'دلوں',
#  'میں',
#  'نقش',
#  'ہیں',
#  'مشہور',
#  'بھارتی',
#  'اداکارہ',
#  'جوہی',
#  'چاولا',
#  'ان',
#  'دنوں',
#  'کراچی',
#  'میں',
#  'موجود',
#  'ہیں90',
#  'کی',
#  'دہائی',
#  'میں',
#  'بالی',
#  'وڈ',
#  'کی',
#  'کئی',
#  'کامیاب',
#  'فلموں',
#  'میں',
#  'اداکاری',
#  'کے',
#  'جوہر',
#  'دکھانے',
#  'والی',
#  'اداکارہ',
#  'جوہی',
#  'چاولا',
#  'پاکستان',
#  'کے',
#  'دورے',
#  'پر',
#  'ہیں',
#  'اور',
#  'شہر',
#  'قائد',
#  'کی',
#  'سیر',
#  'کر',
#  'رہی',
#  'ہیںاداکارہ',
#  'نے',
#  ...]

# %%
import csv
with open('urduwords.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Word'])
    for word in NewsText_words:
        writer.writerow([word])

# %%
# Working on the second xlsx file
import pandas as pd
import numpy as np
df2 = pd.read_excel('Entertainment/output_28.xlsx')
df2
# Out:
#                                               Headline  \
# 0    امریکی سائنس فکشن فلم ارائیولکاپہلاانٹرنیشنل ٹ...
# 1    155زندگیاں بچانے والے پائلٹ کی کہانی پر مبنی ف...
# 2             فلم رستم باکس افس پر 100کروڑ کرنےکے قریب
# 3    جیابچن نے تصویر کھینچنے کی کوشش پر طالب علم کو...
# 4         مومل شیخ کی فلمہپی بھاگ جائے گیاج ریلیز ہوگی
# ..                                                 ...
# 977  گولڈن گلوبز ریوننٹ بہترین فلم بری لاسن بہترین ...
# 978  امیتابھ اور فرحان کی وزیرمداحوں کو متاثر کرنے ...
# 979       شردھا کا34منزلہ عمارت سےرقص کا خطرناک مظاہرہ
# 980    بھرپور نئی ایڈونچر فلم زولینڈر2 کے نئے کلپ جاری
# 981  ایکشن فلم بیٹ مین ورسز سپر مین ڈان اف جسٹس کی ...
#
#                                              News Text       Category  \
# 0    سسپنس سے بھرپور فلموں کے دیوانوں کیلئے خوشخبری...  Entertainment
# 1    حقیقی واقعے پر مبنی ہالی وڈکی ڈرامے سے بھرپور ...  Entertainment
# 2    بولی وڈ فلم رستم نے ریلیز کے پہلے دنوں میں باک...  Entertainment
# 3    بالی ووڈ کی معروف اداکارہ اور سیاستدان جیا بچن...  Entertainment
# 4    مومل شیخ کی رومانس اورمزاح سے بھرپور بالی ووڈ ...  Entertainment
# ..                                                 ...            ...
# 977  کراچیامریکی ریاست کیلیفورنیا اور اس کا مشہور م...  Entertainment
# 978  ممبئیبالی ووڈ کے لیجنڈری اداکار امیتابھ بچن او...  Entertainment
# 979  ممبئی بالی ووڈ کی فلم عاشقی ٹوسے شہرت پانے وال...  Entertainment
# 980  نیویارکہالی وڈ کی کامیڈی سے بھرپور نئی ایڈونچر...  Entertainment
# 981  نیو یارکہالی وڈ کے دو نامور سپر ہیرو بیٹ مین ا...  Entertainment
#
#      News length                                        News Text.1  \
# 0           1011  سسپنس سے بھرپور فلموں کے دیوانوں کیلئے خوشخبری...
# 1           1733  حقیقی واقعے پر مبنی ہالی وڈکی ڈرامے سے بھرپور ...
# 2           1015  بولی وڈ فلم رستم نے ریلیز کے پہلے دنوں میں باک...
# 3           1197  بالی ووڈ کی معروف اداکارہ اور سیاستدان جیا بچن...
# 4           1401  مومل شیخ کی رومانس اورمزاح سے بھرپور بالی ووڈ ...
# ..           ...                                                ...
# 977         1275  کراچیامریکی ریاست کیلیفورنیا اور اس کا مشہور م...
# 978          398  ممبئیبالی ووڈ کے لیجنڈری اداکار امیتابھ بچن او...
# 979          524  ممبئی بالی ووڈ کی فلم عاشقی ٹوسے شہرت پانے وال...
# 980          704  نیویارکہالی وڈ کی کامیڈی سے بھرپور نئی ایڈونچر...
# 981          920  نیو یارکہالی وڈ کے دو نامور سپر ہیرو بیٹ مین ا...
#
#     Subcategory
# 0       Fashion
# 1       Fashion
# 2       Fashion
# 3       Fashion
# 4       Fashion
# ..          ...
# 977     Fashion
# 978     Fashion
# 979     Fashion
# 980     Fashion
# 981     Fashion
#
# [982 rows x 6 columns]

# %%
from pyarabic.araby import tokenize
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import sent_tokenize
nltk.download('punkt')

NewsText_words2 = []
urdu_sentences = df2['News Text']
for i, sent in enumerate(urdu_sentences):
    words = word_tokenize(sent)
    for word in words:
        NewsText_words2.append(word)

NewsText_words2
# Out:
# [nltk_data] Downloading package punkt to /Users/urwah/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['سسپنس',
#  'سے',
#  'بھرپور',
#  'فلموں',
#  'کے',
#  'دیوانوں',
#  'کیلئے',
#  'خوشخبری',
#  'یہ',
#  'ہے',
#  'امریکن',
#  'سائنس',
#  'فکشن',
#  'فلم',
#  'ارائیول',
#  'کاپہلا',
#  'انٹرنیشنل',
#  'ٹریلر',
#  'جاری',
#  'کردیا',
#  'گیا',
#  'ہے',
#  'ڈینس',
#  'ولینیوو',
#  'کی',
#  'ہدایتکاری',
#  'میں',
#  'بننے',
#  'والی',
#  'اس',
#  'فلم',
#  'کی',
#  'کہانی',
#  'ایک',
#  'ایسی',
#  'ٹیم',
#  'کے',
#  'گرد',
#  'گھوم',
#  'رہی',
#  'ہے',
#  'جسے',
#  'ایک',
#  'پراسرار',
#  'اسپیس',
#  'کرافٹ',
#  'کا',
#  'جائزہ',
#  'لینے',
#  'کیلئے',
#  'بھیجا',
#  'جاتا',
#  'ہے',
#  'فلم',
#  'کی',
#  'کاسٹ',
#  'میں',
#  'ایمی',
#  'ایڈمزجیریمی',
#  'رینرفورسٹ',
#  'ویٹیکرمائیکل',
#  'اسٹلبرگٹزی',
#  'مے',
#  'اور',
#  'مارک',
#  'او',
#  'برین',
#  'سمیت',
#  'دیگر',
#  'اداکار',
#  'شامل',
#  'ہیں',
#  'شون',
#  'لیوی',
#  'اور',
#  'ڈین',
#  'لیوین',
#  'کی',
#  'مشترکہ',
#  'پروڈیوس',
#  'کردہ',
#  'یہ',
#  'فلم',
#  'پیراماونٹ',
#  'پکچرز',
#  'کے',
#  'بینر',
#  'تلے',
#  '11نومبر',
#  'کو',
#  'سینما',
#  'گھروں',
#  'کی',
#  'زینت',
#  'بنے',
#  'گی',
#  'سسپنس',
#  'سے',
#  'بھرپور',
#  'فلموں',
#  'کے',
#  'دیوانوں',
#  'کیلئے',
#  'خوشخبری',
#  'یہ',
#  'ہے',
#  'امریکن',
#  'سائنس',
#  'فکشن',
#  'فلم',
#  'ارائیول',
#  'کاپہلا',
#  'انٹرنیشنل',
#  'ٹریلر',
#  'جاری',
#  'کردیا',
#  'گیا',
#  'ہے',
#  'ڈینس',
#  'ولینیوو',
#  'کی',
#  'ہدایتکاری',
#  'میں',
#  'بننے',
#  'والی',
#  'اس',
#  'فلم',
#  'کی',
#  'کہانی',
#  'ایک',
#  'ایسی',
#  'ٹیم',
#  'کے',
#  'گرد',
#  'گھوم',
#  'رہی',
#  'ہے',
#  'جسے',
#  'ایک',
#  'پراسرار',
#  'اسپیس',
#  'کرافٹ',
#  'کا',
#  'جائزہ',
#  'لینے',
#  'کیلئے',
#  'بھیجا',
#  'جاتا',
#  'ہے',
#  'فلم',
#  'کی',
#  'کاسٹ',
#  'میں',
#  'ایمی',
#  'ایڈمزجیریمی',
#  'رینرفورسٹ',
#  'ویٹیکرمائیکل',
#  'اسٹلبرگٹزی',
#  'مے',
#  'اور',
#  'مارک',
#  'او',
#  'برین',
#  'سمیت',
#  'دیگر',
#  'اداکار',
#  'شامل',
#  'ہیں',
#  'شون',
#  'لیوی',
#  'اور',
#  'ڈین',
#  'لیوین',
#  'کی',
#  'مشترکہ',
#  'پروڈیوس',
#  'کردہ',
#  'یہ',
#  'فلم',
#  'پیراماونٹ',
#  'پکچرز',
#  'کے',
#  'بینر',
#  'تلے',
#  '11نومبر',
#  'کو',
#  'سینما',
#  'گھروں',
#  'کی',
#  'زینت',
#  'بنے',
#  'گی',
#  'حقیقی',
#  'واقعے',
#  'پر',
#  'مبنی',
#  'ہالی',
#  'وڈکی',
#  'ڈرامے',
#  'سے',
#  'بھرپور',
#  'نئی',
#  'تھرلر',
#  'فلم',
#  'سلےکا',
#  'نیا',
#  'ٹریلر',
#  'جاری',
#  'کر',
#  'دیا',
#  'گیا',
#  'ہے',
#  'جو',
#  '9ستمبر',
#  'کو',
#  'سنیما',
#  'گھروں',
#  'کی',
#  'زینت',
#  'بنائی',
#  'جائیگی',
#  'کلائینٹ',
#  'ایسٹ',
#  'وڈ',
#  'کی',
#  'اس',
#  'فلم',
#  'کی',
#  'کہانی',
#  'امریکی',
#  'ناول',
#  'سے',
#  'ماخوذ',
#  'ہے',
#  'جس',
#  'کی',
#  'کہانی',
#  'چیسلے',
#  'سولنبرگر',
#  'نامی',
#  'ایک',
#  'ایسے',
#  'بہادر',
#  'امریکی',
#  'پائلٹ',
#  'کی',
#  'گرد',
#  'گھوم',
#  'رہی',
#  'ہے',
#  'جوطیارے',
#  'میں',
#  'خرابی',
#  'کے',
#  'باوجود',
#  '155مسافروں',
#  'کو',
#  'بحفاظت',
#  'زمین',
#  'پر',
#  'اتارنے',
#  'میں',
#  'کامیاب',
#  'ہو',
#  'جاتا',
#  'ہے',
#  'تاہم',
#  'اس',
#  'کارنامے',
#  'کو',
#  'سراہنے',
#  'کے',
#  'بجائے',
#  'پائلٹ',
#  'کے',
#  'خلاف',
#  'تحقیقات',
#  'کو',
#  'حکم',
#  'دے',
#  'دیا',
#  'جاتا',
#  'ہے',
#  '15',
#  'جنوری',
#  '2009',
#  'کو',
#  'نیو',
#  'یارک',
#  'کے',
#  'دریائے',
#  'ہڈسن',
#  'پر',
#  'ہونیوالی',
#  'کریش',
#  'لینڈنگ',
#  'کے',
#  'سچے',
#  'واقعے',
#  'پر',
#  'تشکیل',
#  'دی',
#  'گئی',
#  'اس',
#  'فلم',
#  'میں',
#  'مرکزی',
#  'کردار',
#  'اکیڈمی',
#  'ایوارڈ',
#  'یافتہ',
#  'ہالی',
#  'وڈ',
#  'اداکار',
#  'ٹام',
#  'ہینکس',
#  'نبھا',
#  'رہے',
#  'ہیں',
#  'فلم',
#  'کی',
#  'دیگر',
#  'کاسٹ',
#  'میں',
#  'ارون',
#  'ایکہارٹ',
#  'لاورا',
#  'لینی',
#  'گیری',
#  'ویکس',
#  'اورجیری',
#  'فریراشامل',
#  'ہیں',
#  'فرینک',
#  'مارشل',
#  'کلائینٹ',
#  'ایسٹ',
#  'وڈ',
#  'اور',
#  'ٹم',
#  'مور',
#  'کی',
#  'مشترکہ',
#  'پروڈکشن',
#  'میں',
#  'بننے',
#  'والی',
#  'یہ',
#  'فلم',
#  'وارنر',
#  'بروس',
#  'پکچرز',
#  'کے',
#  'بینر',
#  'تلے',
#  'رواں',
#  'سال9ستمبر',
#  'کو',
#  'سنیما',
#  'گھروں',
#  'میں',
#  'نمائش',
#  'کیلئے',
#  'پیش',
#  'کر',
#  'دی',
#  'جائے',
#  'گی',
#  'حقیقی',
#  'واقعے',
#  'پر',
#  'مبنی',
#  'ہالی',
#  'وڈکی',
#  'ڈرامے',
#  'سے',
#  'بھرپور',
#  'نئی',
#  'تھرلر',
#  'فلم',
#  'سلےکا',
#  'نیا',
#  'ٹریلر',
#  'جاری',
#  'کر',
#  'دیا',
#  'گیا',
#  'ہے',
#  'جو',
#  '9ستمبر',
#  'کو',
#  'سنیما',
#  'گھروں',
#  'کی',
#  'زینت',
#  'بنائی',
#  'جائیگی',
#  'کلائینٹ',
#  'ایسٹ',
#  'وڈ',
#  'کی',
#  'اس',
#  'فلم',
#  'کی',
#  'کہانی',
#  'امریکی',
#  'ناول',
#  'سے',
#  'ماخوذ',
#  'ہے',
#  'جس',
#  'کی',
#  'کہانی',
#  'چیسلے',
#  'سولنبرگر',
#  'نامی',
#  'ایک',
#  'ایسے',
#  'بہادر',
#  'امریکی',
#  'پائلٹ',
#  'کی',
#  'گرد',
#  'گھوم',
#  'رہی',
#  'ہے',
#  'جوطیارے',
#  'میں',
#  'خرابی',
#  'کے',
#  'باوجود',
#  '155مسافروں',
#  'کو',
#  'بحفاظت',
#  'زمین',
#  'پر',
#  'اتارنے',
#  'میں',
#  'کامیاب',
#  'ہو',
#  'جاتا',
#  'ہے',
#  'تاہم',
#  'اس',
#  'کارنامے',
#  'کو',
#  'سراہنے',
#  'کے',
#  'بجائے',
#  'پائلٹ',
#  'کے',
#  'خلاف',
#  'تحقیقات',
#  'کو',
#  'حکم',
#  'دے',
#  'دیا',
#  'جاتا',
#  'ہے',
#  '15',
#  'جنوری',
#  '2009',
#  'کو',
#  'نیو',
#  'یارک',
#  'کے',
#  'دریائے',
#  'ہڈسن',
#  'پر',
#  'ہونیوالی',
#  'کریش',
#  'لینڈنگ',
#  'کے',
#  'سچے',
#  'واقعے',
#  'پر',
#  'تشکیل',
#  'دی',
#  'گئی',
#  'اس',
#  'فلم',
#  'میں',
#  'مرکزی',
#  'کردار',
#  'اکیڈمی',
#  'ایوارڈ',
#  'یافتہ',
#  'ہالی',
#  'وڈ',
#  'اداکار',
#  'ٹام',
#  'ہینکس',
#  'نبھا',
#  'رہے',
#  'ہیں',
#  'فلم',
#  'کی',
#  'دیگر',
#  'کاسٹ',
#  'میں',
#  'ارون',
#  'ایکہارٹ',
#  'لاورا',
#  'لینی',
#  'گیری',
#  'ویکس',
#  'اورجیری',
#  'فریراشامل',
#  'ہیں',
#  'فرینک',
#  'مارشل',
#  'کلائینٹ',
#  'ایسٹ',
#  'وڈ',
#  'اور',
#  'ٹم',
#  'مور',
#  'کی',
#  'مشترکہ',
#  'پروڈکشن',
#  'میں',
#  'بننے',
#  'والی',
#  'یہ',
#  'فلم',
#  'وارنر',
#  'بروس',
#  'پکچرز',
#  'کے',
#  'بینر',
#  'تلے',
#  'رواں',
#  'سال9ستمبر',
#  'کو',
#  'سنیما',
#  'گھروں',
#  'میں',
#  'نمائش',
#  'کیلئے',
#  'پیش',
#  'کر',
#  'دی',
#  'جائے',
#  'گی',
#  'بولی',
#  'وڈ',
#  'فلم',
#  'رستم',
#  'نے',
#  'ریلیز',
#  'کے',
#  'پہلے',
#  'دنوں',
#  'میں',
#  'باکس',
#  'افس',
#  'پر',
#  '88کروڑ',
#  'روپے',
#  'سے',
#  'زیادہ',
#  'کا',
#  'کاروبار',
#  'کر',
#  'لیا',
#  'ہے',
#  'بھارتی',
#  'ذرائع',
#  'ابلاغ',
#  'کے',
#  'مطابق',
#  'تجارتی',
#  'تجزیہ',
#  'نگار',
#  'تارن',
#  'ادارش',
#  'سماجی',
#  'میل',
#  'جول',
#  'کی',
#  'ویب',
#  'سائٹ',
#  'پر',
#  'کہا',
#  'ہے',
#  'کہ',
#  'فلم',
#  'سلطان',
#  'کے',
#  'بعد',
#  'رستم',
#  'رواں',
#  'سال',
#  'ریلیز',
#  'کے',
#  'پہلے',
#  'ہفتے',
#  'میں',
#  'سب',
#  'سے',
#  'زیادہ',
#  'بزنس',
#  'کرنے',
#  'والی',
#  'دوسری',
#  'فلم',
#  'ہے',
#  'انہوں',
#  'نے',
#  'کہا',
#  'کہ',
#  'فلم',
#  'کو',
#  'شائقین',
#  'اور',
#  'ناقدین',
#  'نے',
#  'بہت',
#  'سراہا',
#  'ہے',
#  'اور',
#  'یہ',
#  'جلد',
#  '100',
#  'کروڑ',
#  'کے',
#  'کلب',
#  'میں',
#  'داخل',
#  'ہو',
#  'جائے',
#  'گی',
#  'واضح',
#  'رہے',
#  'کہ',
#  'فلم',
#  'رستم',
#  '12',
#  'اگست',
#  'کو',
#  'ریلیز',
#  'ہوئی',
#  'تھی',
#  'جس',
#  'میں',
#  'اکشے',
#  'کمارایشا',
#  'گپتا',
#  'اور',
#  'الینا',
#  'ڈی',
#  'کروز',
#  'نے',
#  'مرکزی',
#  'کردار',
#  'ادا',
#  'کیا',
#  'ہے',
#  'بولی',
#  'وڈ',
#  'فلم',
#  'رستم',
#  'نے',
#  'ریلیز',
#  'کے',
#  'پہلے',
#  'دنوں',
#  'میں',
#  'باکس',
#  'افس',
#  'پر',
#  '88کروڑ',
#  'روپے',
#  'سے',
#  'زیادہ',
#  'کا',
#  'کاروبار',
#  'کر',
#  'لیا',
#  'ہے',
#  'بھارتی',
#  'ذرائع',
#  'ابلاغ',
#  'کے',
#  'مطابق',
#  'تجارتی',
#  'تجزیہ',
#  'نگار',
#  'تارن',
#  'ادارش',
#  'سماجی',
#  'میل',
#  'جول',
#  'کی',
#  'ویب',
#  'سائٹ',
#  'پر',
#  'کہا',
#  'ہے',
#  'کہ',
#  'فلم',
#  'سلطان',
#  'کے',
#  'بعد',
#  'رستم',
#  'رواں',
#  'سال',
#  'ریلیز',
#  'کے',
#  'پہلے',
#  'ہفتے',
#  'میں',
#  'سب',
#  'سے',
#  'زیادہ',
#  'بزنس',
#  'کرنے',
#  'والی',
#  'دوسری',
#  'فلم',
#  'ہے',
#  'انہوں',
#  'نے',
#  'کہا',
#  'کہ',
#  'فلم',
#  'کو',
#  'شائقین',
#  'اور',
#  'ناقدین',
#  'نے',
#  'بہت',
#  'سراہا',
#  'ہے',
#  'اور',
#  'یہ',
#  'جلد',
#  '100',
#  'کروڑ',
#  'کے',
#  'کلب',
#  'میں',
#  'داخل',
#  'ہو',
#  'جائے',
#  'گی',
#  'واضح',
#  'رہے',
#  'کہ',
#  'فلم',
#  'رستم',
#  '12',
#  'اگست',
#  'کو',
#  'ریلیز',
#  'ہوئی',
#  'تھی',
#  'جس',
#  'میں',
#  'اکشے',
#  'کمارایشا',
#  'گپتا',
#  'اور',
#  'الینا',
#  'ڈی',
#  'کروز',
#  'نے',
#  'مرکزی',
#  'کردار',
#  'ادا',
#  'کیا',
#  'ہے',
#  'بالی',
#  'ووڈ',
#  'کی',
#  'معروف',
#  'اداکارہ',
#  'اور',
#  'سیاستدان',
#  'جیا',
#  'بچن',
#  'اس',
#  'وقت',
#  'سخت',
#  'غصہ',
#  'میں',
#  'اگئیں',
#  'جب',
#  'بھارت',
#  'کے',
#  'ایک',
#  'کالج',
#  'میں',
#  'ہونی',
#  'والی',
#  'تقریب',
#  'کے',
#  'دوران',
#  'طالبعلم',
#  'نے',
#  'ان',
#  'کی',
#  'تصویر',
#  'کھینچنے',
#  'کی',
#  'کوشش',
#  'کی',
#  'توانہوں',
#  'نے',
#  'بات',
#  'ادھوری',
#  'چھوڑ',
#  'کر',
#  'اس',
#  'طالبعلم',
#  'کو',
#  'سختی',
#  'سے',
#  'ڈانٹ',
#  'دیا',
#  'بھارتی',
#  'میڈیا',
#  'رپورٹس',
#  'کے',
#  'مطابق',
#  'جیا',
#  'بچن',
#  'نے',
#  'غصہ',
#  'میں',
#  'اکر',
#  'بھارتیوں',
#  'کو',
#  'تمیز',
#  'اور',
#  'تہذیب',
#  'سیکھنے',
#  'کا',
#  'مشورہ',
#  'دے',
#  'ڈالا',
#  'اور',
#  'کہا',
#  'کہ',
#  'یہ',
#  'تہذیب',
#  'کا',
#  'ایک',
#  'بنیادی',
#  'اصول',
#  'ہے',
#  'کہ',
#  'کسی',
#  'کو',
#  'گفتگو',
#  'کے',
#  'دوران',
#  'مخل',
#  'نہ',
#  'کیا',
#  'جائے',
#  'اور',
#  'ہم',
#  'بھارتیوں',
#  'کو',
#  'شدت',
#  'سے',
#  'اسے',
#  'سیکھنے',
#  'کی',
#  'ضرورت',
#  'ہے',
#  'انہوں',
#  'نے',
#  'مزید',
#  'کہا',
#  'کہ',
#  'لوگ',
#  'کہیں',
#  'بھی',
#  'کسی',
#  'کی',
#  'بھی',
#  'بغیر',
#  'پوچھے',
#  'تصویر',
#  'کھینچنے',
#  'لگتے',
#  'ہیں',
#  'اس',
#  'لئے',
#  'یہ',
#  'میرا',
#  'حق',
#  'ہے',
#  'کہ',
#  'میں',
#  'اپ',
#  'کو',
#  'اپنی',
#  'تصویر',
#  'نہ',
#  'کھینچنے',
#  'دوں',
#  'بالی',
#  'ووڈ',
#  'کی',
#  'معروف',
#  'اداکارہ',
#  'اور',
#  'سیاستدان',
#  'جیا',
#  'بچن',
#  'اس',
#  'وقت',
#  'سخت',
#  'غصہ',
#  'میں',
#  'اگئیں',
#  'جب',
#  'بھارت',
#  'کے',
#  'ایک',
#  'کالج',
#  'میں',
#  'ہونی',
#  'والی',
#  'تقریب',
#  'کے',
#  'دوران',
#  'طالبعلم',
#  'نے',
#  'ان',
#  'کی',
#  'تصویر',
#  'کھینچنے',
#  'کی',
#  'کوشش',
#  'کی',
#  'توانہوں',
#  'نے',
#  'بات',
#  'ادھوری',
#  'چھوڑ',
#  'کر',
#  'اس',
#  'طالبعلم',
#  'کو',
#  'سختی',
#  'سے',
#  'ڈانٹ',
#  'دیا',
#  'بھارتی',
#  'میڈیا',
#  'رپورٹس',
#  'کے',
#  'مطابق',
#  'جیا',
#  'بچن',
#  'نے',
#  'غصہ',
#  'میں',
#  'اکر',
#  'بھارتیوں',
#  'کو',
#  'تمیز',
#  'اور',
#  'تہذیب',
#  'سیکھنے',
#  'کا',
#  'مشورہ',
#  'دے',
#  'ڈالا',
#  'اور',
#  'کہا',
#  'کہ',
#  'یہ',
#  'تہذیب',
#  'کا',
#  'ایک',
#  'بنیادی',
#  'اصول',
#  'ہے',
#  'کہ',
#  'کسی',
#  'کو',
#  'گفتگو',
#  'کے',
#  'دوران',
#  'مخل',
#  'نہ',
#  'کیا',
#  'جائے',
#  'اور',
#  'ہم',
#  'بھارتیوں',
#  'کو',
#  'شدت',
#  'سے',
#  'اسے',
#  ...]
